# %%
import sys, os
import numpy as np

sys.path.insert(0, "/Users/Shared/auto/07p/python")
# sys.path.insert(0, "/Users/ielyaascloete/auto/07p/python")
from auto import *

# %%
cl
# Out:
# <function AUTOCommands.cl>

# %%
import sys
print(sys.version)
# Out:
# 2.7.14 |Anaconda custom (64-bit)| (default, Dec  7 2017, 11:07:58)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]

# %%
Eq = run(e='P2Y',c='P2Y.eq')
# Out:
# Starting P2Y ...
#
#   BR    PT  TY  LAB     V_plc        L2-NORM        V_pkc         switch        delta         K_tau        tau_max       PAR(21)
#    1     1  EP    1   1.00000E-10   4.05086E+00   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03   1.00000E+00
#    1   140  HB    2   5.30230E-04   3.32886E+00   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03   9.22711E-01
#    1   197  LP    3   5.98240E-04   2.77568E+00   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03   8.39625E-01
#    1   265  LP    4   5.61486E-04   2.11146E+00   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03   6.94457E-01
#    1   332  HB    5   8.13779E-04   1.45685E+00   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03   5.65826E-01
#    1   442  HB    6   1.19826E-02   4.84750E-01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03   3.15143E-01
#    1  1485  EP    7   1.00042E+01   1.89789E+00   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03   6.85683E-02
#
#  Total Time    0.174E+00
# P2Y ... done
# Note: The following floating-point exceptions are signalling: IEEE_UNDERFLOW_FLAG IEEE_DENORMAL

# %%
HB12P = run(Eq('HB1'),c ='P2Y.eq',ISW=2,ICP=[5,6],DS=1e-3)

# %%
HB22P = run(Eq('HB2'),c ='P2Y.eq',ISW=2,ICP=[5,6],DS=1e-3)

# %%
HB12Pm = run(Eq('HB1'),c ='P2Y.eq',ISW=2,ICP=[5,6],DS=-1e-3,SP=['BP0','LP0'])

# %%
HB22Pm = run(Eq('HB2'),c ='P2Y.eq',ISW=2,ICP=[5,6],DS=-1e-3,SP=['BP0','LP0'])

# %%
Hom1 = run(Eq('HB1'),c ='P2Y.eq',ISW=2,ICP=[1,4],DS=1e-3)

# %%
Hom_2 = run(Eq('HB2'),c ='P2Y.eq',ISW=2,ICP=[1,4],DS=1e-3)

# %%
Hom1 = run(Eq('HB1'),c ='P2Y.eq',ISW=2,ICP=[1,4],DS=-1e-3)

# %%
PO1 = run(Eq('HB1'),c ='P2Y.per',SP=['BP0'],DS=1e-3,EPSL=1e-4,EPSU=1e-6,EPSS=1e-6)
# Out:
# Starting P2Y ...
#
#   BR    PT  TY  LAB     V_plc        L2-NORM        PERIOD        V_pkc         switch        delta         K_tau        tau_max
#    2    34  LP    8   5.24988E-04   3.16903E+00   1.91495E+02   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    2   144  LP    9   2.54928E-03   2.84313E+00   2.09192E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    2   368  LP   10   2.54928E-03   2.84313E+00   2.09192E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    2   478  LP   11   5.24988E-04   3.16903E+00   1.91495E+02   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    2   505  MX   12   5.30006E-04   3.32973E+00   4.97859E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#
#  Total Time    0.190E+01
# P2Y ... done
# Note: The following floating-point exceptions are signalling: IEEE_UNDERFLOW_FLAG IEEE_DENORMAL

# %%
PO2 = run(Eq('HB3'),c ='P2Y.per',SP=['BP0'],DS=1e-3,EPSL=1e-4,EPSU=1e-4,EPSS=1e-4)
# Out:
# Starting P2Y ...
#
#   BR    PT  TY  LAB     V_plc        L2-NORM        PERIOD        V_pkc         switch        delta         K_tau        tau_max
#    6    26  LP    8   9.81700E-03   6.15255E-01   2.52792E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    6    50  LP    9   1.34839E-02   7.85351E-01   3.61364E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    6    76  LP   10   1.04373E-02   8.34589E-01   3.08657E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    6    87  LP   11   1.04498E-02   8.23765E-01   2.95079E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    6   106  PD   12   1.03322E-02   8.81851E-01   2.84532E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    6   215  PD   13   7.77853E-03   1.82596E+00   1.67943E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    6   253  LP   14   3.73096E-03   2.04964E+00   7.45465E+00   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    6   285  LP   15   4.66886E-03   1.75790E+00   1.60184E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    6   304  LP   16   2.61186E-03   1.70225E+00   1.36147E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    6   307  MX   17   2.61168E-03   1.70224E+00   1.36145E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#
#  Total Time    0.140E+01
# P2Y ... done
# Note: The following floating-point exceptions are signalling: IEEE_UNDERFLOW_FLAG IEEE_DENORMAL

# %%
PO = PO1 + PO2

# %%
Is_1 = run(e='P2Y',c='P2Y.per',dat='p2y_per09',ISW=1,PAR={1:0.09},ISP=2,EPSL= 1e-12, EPSU = 1e-12,NTST=200)
Is_2 = run(e='P2Y',c='P2Y.per',dat='p2y_per09', DS='-',ISW=1,SP=['BP0'],PAR={1:0.09},ISP=2,EPSL= 1e-12, EPSU = 1e-12,NTST=200)
Is = Is_1 + Is_2

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def auto_to_csv(branch,name,solution_type):
    """ The goal of this function is to save as a csv file the results of an AUTO continuation 
        and return a panda dataframe of the data"""
    """ Input:
        branch: an AUTO branch solution acquired using run(blablabla)
        name: The name of the output csv file, must be a string
        solution_type: 'EQ' for equilibrium, 'PR' for periodic orbit, 'HB' for Hopf two parameters continuation
            'LPPR' Limit point of periodic orbit
        
        Output:
        panda dataframe of the branch solution"""
    
    
    """Relabelling the branch solution """
    branch = rl(branch)
    """Saving the branch solution"""
    sv(branch,name)
    
    """Acquire the b. file"""
    print("Acquire the b. file")
    name_b = 'b.' + name
    content = None
    with open(name_b, 'r') as f:
        content = f.readlines()
    
    
    print("Read file")
    """Read the file from the beginning of the interesting part (depends on its type)"""
    
    for i in range(len(content)):
    
        if "PT" in content[i]:
            init = i
            break



            
    content_csv = [[el for el in content[init].split(' ') if len(el) > 0 and el != '\n']]
    print(content_csv)
        
    
        
    print("Rename branch")
    """ Rename the branch"""
    content_csv[0][0] = 'branch'
    column_names = content_csv[0]
    
    
    
    print("Split content")
    """Split and read the content"""
    for line in content:
        dummy = line.split(' ')
        dummy = [el for el in dummy if len(el) > 0 and el != '\n']
        if dummy[0] == '0':
            continue

        for el_i, el in enumerate(dummy):
            if el_i < 4:
                dummy[el_i] = int(el)
            else:
                dummy[el_i] = float(el)

        if len(dummy) > 1:
            content_csv.append(dummy)
        
    # transform into panda data frame
        
    df = pd.DataFrame(content_csv, columns=column_names)
    
    # Export to csv
    name_csv = name + '.csv'
    df[1:-1].to_csv(name_csv)

        
    
    
    
    return df[1:-1]

# %%
df_eq = auto_to_csv(Eq,'Eq','EQ')
# Out:
# Relabeling done
# Saving to b.Eq, s.Eq, and d.Eq ... done
# Acquire the b. file
# Read file
# [['0', 'PT', 'TY', 'LAB', 'V_plc', 'L2-NORM', 'V_pkc', 'switch', 'delta', 'K_tau', 'tau_max', 'PAR(21)', 'PAR(22)', 'PAR(23)', 'PAR(24)', 'PAR(25)', 'PAR(26)', 'PAR(31)', 'PAR(32)', 'PAR(33)', 'PAR(34)', 'PAR(35)', 'PAR(36)', 'PAR(80)']]
# Rename branch
# Split content

# %%
df_PR = auto_to_csv(PO,'PO','PR')
# Out:
# Relabeling done
# Saving to b.PO, s.PO, and d.PO ... done
# Acquire the b. file
# Read file
# [['0', 'PT', 'TY', 'LAB', 'V_plc', 'L2-NORM', 'PERIOD', 'V_pkc', 'switch', 'delta', 'K_tau', 'tau_max', 'PAR(21)', 'PAR(22)', 'PAR(23)', 'PAR(24)', 'PAR(25)', 'PAR(26)', 'PAR(31)', 'PAR(32)', 'PAR(33)', 'PAR(34)', 'PAR(35)', 'PAR(36)', 'PAR(80)']]
# Rename branch
# Split content

# %%
df_HB12P = auto_to_csv(HB12P,'HB12P','HB')

# %%
df_HB22P = auto_to_csv(HB22P,'HB22P','HB')

# %%
df_HB12Pm = auto_to_csv(HB12Pm,'HB12Pm','HB')

# %%
df_HB22Pm = auto_to_csv(HB22Pm,'HB22Pm','HB')

# %%
df_Hom1 = auto_to_csv(Hom1,'Hom1','HB')

# %%
df_Hom_2 = auto_to_csv(Hom_2,'Hom_2','HB')

# %%
import plotly.plotly as py
from plotly.graph_objs import *
from plotly.offline import iplot, init_notebook_mode
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
trace_eq = Scatter(x=df_eq['V_plc'],
                  y=df_eq['PAR(22)'],
                  name='Equilibria',
                  mode = 'lines')
trace_per = Scatter(x=df_PR['V_plc'],
                  y=df_PR['PAR(22)'],
                  name='Periodic Orbit',
                   mode='lines')
trace_per_min = Scatter(x=df_PR['V_plc'],
                  y=df_PR['PAR(32)'],
                  name='Periodic Orbit',
                   mode='lines')
data = [trace_eq,trace_per,trace_per_min]
layout = Layout(title="Bifurcation diagram",
               xaxis=dict(title='V_plc'),
               yaxis=dict(title='[Ca]'))
fig = Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div id="eca92215-8529-4e11-a715-a410b97a9e7a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("eca92215-8529-4e11-a715-a410b97a9e7a", [{"y": [0.080529600382, 0.080529583755, 0.080529583771, 0.080529583829, 0.080529584037, 0.08052958483, 0.08052958792, 0.080529596315, 0.080529617351, 0.080529667838, 0.080529785781, 0.08052995351, 0.08053016972, 0.080530432798, 0.080530740879, 0.080531091916, 0.080531483736, 0.080531914102, 0.08053238076, 0.080533143979, 0.080533976595, 0.080534871801, 0.080535823332, 0.080536825507, 0.080537873221, 0.080538961922, 0.080540663175, 0.080542435897, 0.080544270311, 0.080546158275, 0.080548092989, 0.080550068754, 0.080553099142, 0.080556197993, 0.080559354859, 0.080562561401, 0.080565810886, 0.080569097816, 0.08057408878, 0.080579141683, 0.080584247035, 0.080589397359, 0.080594586676, 0.080602433473, 0.080610344378, 0.080618309575, 0.080626321435, 0.08063437392, 0.080646518522, 0.080658730977, 0.080671001611, 0.080683322948, 0.080695689099, 0.080714312345, 0.080733013574, 0.080751783445, 0.080770614755, 0.080789501842, 0.080817927449, 0.08084645664, 0.080875080475, 0.080903792075, 0.08093258604, 0.080975922285, 0.081019423031, 0.081063079826, 0.081106886202, 0.081172865551, 0.081239157422, 0.081305752467, 0.081372643752, 0.081439826043, 0.081541136674, 0.081643083363, 0.081745659342, 0.081848859977, 0.081997233006, 0.082146866972, 0.082297759521, 0.082449910365, 0.08260332066, 0.082757992591, 0.082913929089, 0.083071133632, 0.0832296101, 0.083389362669, 0.083550395732, 0.083712713833, 0.083876321625, 0.084041223827, 0.084207425194, 0.084374930494, 0.084543744482, 0.084713871889, 0.0848853174, 0.085058085646, 0.08523218119, 0.085407608517, 0.085584372026, 0.085762476018, 0.085941924693, 0.086122722142, 0.086304872337, 0.086488379129, 0.086673246239, 0.086859477255, 0.087047075623, 0.087236044646, 0.087426387477, 0.087618107114, 0.087811206395, 0.088005687993, 0.088201554416, 0.088398807994, 0.088597450882, 0.088797485053, 0.088998912293, 0.089201734198, 0.08940595217, 0.089611567409, 0.089818580916, 0.090026993482, 0.090236805688, 0.090448017898, 0.090660630258, 0.090874642689, 0.091090054887, 0.091306866314, 0.091525076195, 0.091744683518, 0.091965687026, 0.092188085213, 0.092411876323, 0.092637058343, 0.092863628998, 0.093091585752, 0.093320925799, 0.09355164606, 0.093783743181, 0.093992079041, 0.094226771859, 0.094462830238, 0.094700249707, 0.094939025498, 0.095179152545, 0.095420625472, 0.095663438596, 0.095907585921, 0.09615306113, 0.096399857587, 0.096647968326, 0.096897386053, 0.097148103135, 0.097400111603, 0.097653403141, 0.097907969085, 0.098163800418, 0.098420887765, 0.09867922139, 0.09893879119, 0.09919958669, 0.099461597041, 0.099724811015, 0.099989216996, 0.10025480298, 0.10052155658, 0.10078946499, 0.10105851503, 0.10132869308, 0.10159998515, 0.10187237679, 0.10214585317, 0.10242039902, 0.10269599864, 0.10297263591, 0.10325029426, 0.1035289567, 0.10380860578, 0.10408922361, 0.10437079186, 0.10465329174, 0.104936704, 0.10522100895, 0.10550618641, 0.10579221576, 0.10607907592, 0.1063667453, 0.10665520189, 0.10694442319, 0.10723438621, 0.10752506751, 0.10781644317, 0.10810848877, 0.10840117946, 0.10869448988, 0.10898839419, 0.10907849172, 0.10937313208, 0.10966830498, 0.10996398302, 0.11026013834, 0.11055674262, 0.11085376706, 0.1111511824, 0.11144895895, 0.11174706652, 0.11204547451, 0.11234415184, 0.11264306704, 0.11294218814, 0.11324148281, 0.11354091824, 0.11384046125, 0.11414007823, 0.11443973518, 0.1147393977, 0.11503903102, 0.11533860001, 0.11563806915, 0.1159374026, 0.11623656414, 0.11653551728, 0.11683422516, 0.11713265064, 0.1174307563, 0.11772850443, 0.11802585706, 0.11832277596, 0.1186192227, 0.1189151586, 0.11921054479, 0.11950534221, 0.11979951166, 0.12009301375, 0.12038580898, 0.120677857 ...

# %%
Is_3 = run(e='PKC_HR_IPR',c='PKC_HR_IPR.per',dat='per6',ISW=1,PAR={1:0.6},ISP=2,EPSL= 1e-12, EPSU = 1e-12,NTST=200)
Is_4 = run(e='PKC_HR_IPR',c='PKC_HR_IPR.per',dat='per6', DS='-',ISW=1,SP=['BP0'],PAR={1:0.6},ISP=2,EPSL= 1e-12, EPSU = 1e-12,NTST=200)
Is2 = Is_3 + Is_4

# %%
Is_5 = run(e='PKC_HR_IPR',c='PKC_HR_IPR.per',dat='per3',ISW=1,PAR={1:0.3},ISP=2,EPSL= 1e-12, EPSU = 1e-12,NTST=200)
Is_6 = run(e='PKC_HR_IPR',c='PKC_HR_IPR.per',dat='per3', DS='-',ISW=1,SP=['BP0'],PAR={1:0.3},ISP=2,EPSL= 1e-12, EPSU = 1e-12,NTST=200)
Is3 = Is_5 + Is_6

# %%
#Is_3 = run(e='PKC_HR_IPR',c='PKC_HR_IPR.per',dat='per3',ISW=1,PAR={1:0.3},ISP=2,EPSL= 1e-12, EPSU = 1e-12,NTST=200)
#Is_4 = run(e='PKC_HR_IPR',c='PKC_HR_IPR.per',dat='per3', DS='-',ISW=1,SP=['BP0'],PAR={1:0.3},ISP=2,EPSL= 1e-12, EPSU = 1e-12,NTST=200)
#Is2 = Is_3 + Is_4

# %%
Is_5 = run(e='PKC_HR_IPR',c='PKC_HR_IPR.per',dat='per6',ISW=1,PAR={1:0.6},ISP=2,EPSL= 1e-12, EPSU = 1e-12,NTST=200)
Is_6 = run(e='PKC_HR_IPR',c='PKC_HR_IPR.per',dat='per6', DS='-',ISW=1,SP=['BP0'],PAR={1:0.6},ISP=2,EPSL= 1e-12, EPSU = 1e-12,NTST=200)
Is3 = Is_5 + Is_6

# %%
df_Is = auto_to_csv(Is,'Is','IS')

# %%
df_Is2 = auto_to_csv(Is2,'Is2','IS2')

# %%
df_Is3 = auto_to_csv(Is3,'Is3','IS3')

# %%
trace_eq = Scatter(x=df_eq['V_plc'],
                  y=df_eq['PAR(5)'],
                  name='Equilibria',
                  mode = 'lines')
trace_per = Scatter(x=df_PR['V_plc'],
                  y=df_PR['PAR(5)'],
                  name='Periodic Orbit',
                   mode='lines')
trace_per_min = Scatter(x=df_PR['V_plc'],
                  y=df_PR['PAR(32)'],
                  name='Periodic Orbit',
                   mode='lines')
tr_is = Scatter(x=df_Is['V_plc'],
                  y=df_Is['PAR(5)'],
                  name='Isola',
                  mode='lines')
tr_is_min = Scatter(x=df_Is['V_plc'],
                  y=df_Is['PAR(32)'],
                  name='Isola',
                  mode='lines')
tr_is2 = Scatter(x=df_Is2['V_plc'],
                  y=df_Is2['PAR(5)'],
                  name='Isola',
                  mode='lines')
tr_is2_min = Scatter(x=df_Is2['V_plc'],
                  y=df_Is2['PAR(32)'],
                  name='Isola',
                  mode='lines')
tr_is3 = Scatter(x=df_Is3['V_plc'],
                  y=df_Is3['PAR(5)'],
                  name='Isola',
                  mode='lines')
tr_is3_min = Scatter(x=df_Is3['V_plc'],
                  y=df_Is3['PAR(32)'],
                  name='Isola',
                  mode='lines')
data = [trace_eq,trace_per,trace_per_min,tr_is,tr_is_min,tr_is2,tr_is2_min,tr_is3,tr_is3_min]
# data = [trace_eq,trace_per,trace_per_min,tr_is,tr_is_min,tr_is2,tr_is2_min]
layout = Layout(title="Bifurcation diagram",
               xaxis=dict(title='V_plc'),
               yaxis=dict(title='[Ca]'))
fig = Figure(data=data, layout=layout)
iplot(fig)

# %%
HB12P = run(Eq('HB1'),c ='PKC_HR_IPR.eq',ISW=2,ICP=[1,2],DS=1e-3)

# %%
HB22P = run(Eq('HB2'),c ='PKC_HR_IPR.eq',ISW=2,ICP=[1,2],DS=1e-3,NMX=100000)

# %%
PD2P = run(PO1('PD1'),c='PKC_HR_IPR.per',ISW=2,ICP=[1,2,11],DS=1e-4)
PD2P1 = run(PD2P('EP1'))

# %%
SNP2P = run(PO1('LP3'),c='PKC_HR_IPR.per',ISW=2,ICP=[1,2,11],DS=1e-4)
SNP2P1 = run(SNP2P('EP1'))

# %%
df_HB12P = auto_to_csv(HB12P,'HB12P','HB_1')
df_HB22P = auto_to_csv(HB22P,'HB22P','HB_2')
df_PD2P1 = auto_to_csv(PD2P1,'PD2P1','PD_1')
df_SNP2P1 = auto_to_csv(SNP2P1,'SNP2P1','SNP_1')

# %%
slice1 = run(e='PKC_HR_IPR',c='PKC_HR_IPR.eq',PAR={2:0.01})

# %%
slicePO = run(slice1('HB1'),c='PKC_HR_IPR.per',SP=['BP0'])

# %%
slice2 = run(e='PKC_HR_IPR',c='PKC_HR_IPR.eq',PAR={2:0.2})

# %%
slicePO2 = run(slice1('HB2'),c='PKC_HR_IPR.per',SP=['BP0'])

# %%
slice3 = run(e='PKC_HR_IPR',c='PKC_HR_IPR.eq',PAR={2:14})

# %%
slicePO3 = run(slice3('HB1'),c='PKC_HR_IPR.per',SP=['BP0'])

# %%
slice4 = run(e='PKC_HR_IPR',c='PKC_HR_IPR.eq',PAR={2:20})

# %%
slicePO4 = run(slice4('HB1'),c='PKC_HR_IPR.per',SP=['BP0'])

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def auto_to_csv(branch,name,solution_type):
    """ The goal of this function is to save as a csv file the results of an AUTO continuation 
        and return a panda dataframe of the data"""
    """ Input:
        branch: an AUTO branch solution acquired using run(blablabla)
        name: The name of the output csv file, must be a string
        solution_type: 'EQ' for equilibrium, 'PR' for periodic orbit, 'HB' for Hopf two parameters continuation
            'LPPR' Limit point of periodic orbit
        
        Output:
        panda dataframe of the branch solution"""
    
    
    """Relabelling the branch solution """
    branch = rl(branch)
    """Saving the branch solution"""
    sv(branch,name)
    
    """Acquire the b. file"""
    print("Acquire the b. file")
    name_b = 'b.' + name
    content = None
    with open(name_b, 'r') as f:
        content = f.readlines()
    
    
    print("Read file")
    """Read the file from the beginning of the interesting part (depends on its type)"""
    
    for i in range(len(content)):
    
        if "PT" in content[i]:
            init = i
            break



            
    content_csv = [[el for el in content[init].split(' ') if len(el) > 0 and el != '\n']]
    print(content_csv)
        
    
        
    print("Rename branch")
    """ Rename the branch"""
    content_csv[0][0] = 'branch'
    column_names = content_csv[0]
    
    
    
    print("Split content")
    """Split and read the content"""
    for line in content:
        dummy = line.split(' ')
        dummy = [el for el in dummy if len(el) > 0 and el != '\n']
        if dummy[0] == '0':
            continue

        for el_i, el in enumerate(dummy):
            if el_i < 4:
                dummy[el_i] = int(el)
            else:
                dummy[el_i] = float(el)

        if len(dummy) > 1:
            content_csv.append(dummy)
        
    # transform into panda data frame
        
    df = pd.DataFrame(content_csv, columns=column_names)
    
    # Export to csv
    name_csv = name + '.csv'
    df[1:-1].to_csv(name_csv)

        
    
    
    
    return df[1:-1]

# %%
df_eq = auto_to_csv(slice1,'slice1','EQ')

# %%
df_PR = auto_to_csv(slicePO,'slicePO','PR')

# %%
trace_eq = Scatter(x=df_eqs[8]['ct'],
                  y=df_eqs[8]['PAR(5)'],
                  name='Equilibria',
                  mode = 'lines')
trace_per = Scatter(x=df_PRs[8]['ct'],
                  y=df_PRs[8]['PAR(5)'],
                  name='Periodic Orbit',
                   mode='lines')
trace_per_min = Scatter(x=df_PRs[8]['ct'],
                  y=df_PRs[8]['PAR(8)'],
                  name='Periodic Orbit',
                   mode='lines')
data = [trace_eq,trace_per,trace_per_min]
layout = Layout(title="Bifurcation diagram",
               xaxis=dict(title='Agonist'),
               yaxis=dict(title='[Ca]'))
fig = Figure(data=data, layout=layout)
iplot(fig)

# %%
df_per1[1:-1].to_csv('per1.csv')

# %%
df_per2[1:-1].to_csv('per2.csv')

# %%
df_per2[1:-1]
