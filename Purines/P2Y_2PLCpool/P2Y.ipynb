# %%
import sys, os
import numpy as np

sys.path.insert(0, "/Users/Shared/auto/07p/python")
# sys.path.insert(0, "/Users/ielyaascloete/auto/07p/python")
from auto import *

# %%
cl
# Out:
# <function AUTOCommands.cl>

# %%
import sys
print(sys.version)
# Out:
# 2.7.14 |Anaconda custom (64-bit)| (default, Dec  7 2017, 11:07:58)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]

# %%
Eq = run(e='P2Y',c='P2Y.eq')
# Out:
# gfortran -fopenmp -O -c P2Y.f90 -o P2Y.o
# gfortran -fopenmp -O P2Y.o -o P2Y.exe /Users/Shared/auto/07p/lib/*.o
# Starting P2Y ...
#
#   BR    PT  TY  LAB     V_plc        L2-NORM        V_pkc         switch        delta         K_tau        tau_max       PAR(21)
#    1     1  EP    1   1.00000E-10   4.05086E+00   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03   1.00000E+00
#    1   140  HB    2   7.48186E-04   3.33159E+00   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03   9.23022E-01
#    1   292  HB    3   2.84906E-03   1.83716E+00   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03   6.35363E-01
#    1   441  HB    4   2.17530E-02   4.84423E-01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03   3.14891E-01
#    1  1481  EP    5   1.00034E+01   1.89583E+00   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03   6.85895E-02
#
#  Total Time    0.284E+00
# P2Y ... done
# Note: The following floating-point exceptions are signalling: IEEE_UNDERFLOW_FLAG IEEE_DENORMAL

# %%
HB12P = run(Eq('HB1'),c ='P2Y.eq',ISW=2,ICP=[5,6],DS=1e-3)

# %%
HB22P = run(Eq('HB2'),c ='P2Y.eq',ISW=2,ICP=[5,6],DS=1e-3)

# %%
HB12Pm = run(Eq('HB1'),c ='P2Y.eq',ISW=2,ICP=[5,6],DS=-1e-3,SP=['BP0','LP0'])

# %%
HB22Pm = run(Eq('HB2'),c ='P2Y.eq',ISW=2,ICP=[5,6],DS=-1e-3,SP=['BP0','LP0'])

# %%
Hom1 = run(Eq('HB1'),c ='P2Y.eq',ISW=2,ICP=[1,4],DS=1e-3)

# %%
Hom_2 = run(Eq('HB2'),c ='P2Y.eq',ISW=2,ICP=[1,4],DS=1e-3)

# %%
Hom1 = run(Eq('HB1'),c ='P2Y.eq',ISW=2,ICP=[1,4],DS=-1e-3)

# %%
PO1 = run(Eq('HB1'),c ='P2Y.per',SP=['BP0'],DS=1e-3,EPSL=1e-4,EPSU=1e-6,EPSS=1e-6)
# Out:
# Starting P2Y ...
#
#   BR    PT  TY  LAB     V_plc        L2-NORM        PERIOD        V_pkc         switch        delta         K_tau        tau_max
#    2     9  TR    6   7.49989E-04   3.32494E+00   6.00969E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    2   143  TR    7   3.91524E-03   2.77334E+00   1.85076E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    2   144  LP    8   3.91531E-03   2.77018E+00   1.84457E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    2   352  LP    9   3.91531E-03   2.77018E+00   1.84456E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    2   487  TR   10   7.49989E-04   3.32494E+00   6.00952E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    2   619  LP   11   3.91531E-03   2.77018E+00   1.84457E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    2   827  LP   12   3.91531E-03   2.77018E+00   1.84456E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    2   962  TR   13   7.49989E-04   3.32494E+00   6.00959E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    2  1094  LP   14   3.91531E-03   2.77018E+00   1.84457E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    2  1302  LP   15   3.91531E-03   2.77018E+00   1.84456E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    2  1437  TR   16   7.49989E-04   3.32494E+00   6.00961E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    2  1569  LP   17   3.91531E-03   2.77018E+00   1.84457E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    2  1777  LP   18   3.91531E-03   2.77018E+00   1.84456E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    2  1912  TR   19   7.49989E-04   3.32494E+00   6.00952E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    2  2000       20   1.65955E-03   3.16833E+00   6.15781E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    2  2044  LP   21   3.91531E-03   2.77018E+00   1.84457E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    2  2252  LP   22   3.91531E-03   2.77018E+00   1.84456E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    2  2387  TR   23   7.49989E-04   3.32494E+00   6.00957E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    2  2519  LP   24   3.91531E-03   2.77018E+00   1.84457E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    2  2727  LP   25   3.91531E-03   2.77018E+00   1.84456E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    2
+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    2  9787  LP  313   3.91531E-03   2.77018E+00   1.84456E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    2  9922  TR  314   7.49989E-04   3.32494E+00   6.00956E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    2     5  EP  315   1.40670E-03   3.21252E+00   7.51572E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#
#  Total Time    0.172E+03
# P2Y ... done
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_OVERFLOW_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL

# %%
PO2 = run(Eq('HB3'),c ='P2Y.per',SP=['BP0'],DS=1e-3,EPSL=1e-4,EPSU=1e-4,EPSS=1e-4)
# Out:
# Starting P2Y ...
#
#   BR    PT  TY  LAB     V_plc        L2-NORM        PERIOD        V_pkc         switch        delta         K_tau        tau_max
#    4    30  LP    6   1.83182E-02   6.42055E-01   2.69029E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    4    51  LP    7   2.10093E-02   8.09131E-01   3.50387E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#    4   172  MX    8   1.15621E-02   1.10817E+00   3.30685E+01   1.00000E-01   1.00000E+00   2.50000E+00   2.00000E-01   2.00000E+03
#
#  Total Time    0.892E+00
# P2Y ... done
# Note: The following floating-point exceptions are signalling: IEEE_UNDERFLOW_FLAG IEEE_DENORMAL

# %%
PO = PO1 + PO2

# %%
Is_1 = run(e='P2Y',c='P2Y.per',dat='p2y_per09',ISW=1,PAR={1:0.09},ISP=2,EPSL= 1e-12, EPSU = 1e-12,NTST=200)
Is_2 = run(e='P2Y',c='P2Y.per',dat='p2y_per09', DS='-',ISW=1,SP=['BP0'],PAR={1:0.09},ISP=2,EPSL= 1e-12, EPSU = 1e-12,NTST=200)
Is = Is_1 + Is_2

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def auto_to_csv(branch,name,solution_type):
    """ The goal of this function is to save as a csv file the results of an AUTO continuation 
        and return a panda dataframe of the data"""
    """ Input:
        branch: an AUTO branch solution acquired using run(blablabla)
        name: The name of the output csv file, must be a string
        solution_type: 'EQ' for equilibrium, 'PR' for periodic orbit, 'HB' for Hopf two parameters continuation
            'LPPR' Limit point of periodic orbit
        
        Output:
        panda dataframe of the branch solution"""
    
    
    """Relabelling the branch solution """
    branch = rl(branch)
    """Saving the branch solution"""
    sv(branch,name)
    
    """Acquire the b. file"""
    print("Acquire the b. file")
    name_b = 'b.' + name
    content = None
    with open(name_b, 'r') as f:
        content = f.readlines()
    
    
    print("Read file")
    """Read the file from the beginning of the interesting part (depends on its type)"""
    
    for i in range(len(content)):
    
        if "PT" in content[i]:
            init = i
            break



            
    content_csv = [[el for el in content[init].split(' ') if len(el) > 0 and el != '\n']]
    print(content_csv)
        
    
        
    print("Rename branch")
    """ Rename the branch"""
    content_csv[0][0] = 'branch'
    column_names = content_csv[0]
    
    
    
    print("Split content")
    """Split and read the content"""
    for line in content:
        dummy = line.split(' ')
        dummy = [el for el in dummy if len(el) > 0 and el != '\n']
        if dummy[0] == '0':
            continue

        for el_i, el in enumerate(dummy):
            if el_i < 4:
                dummy[el_i] = int(el)
            else:
                dummy[el_i] = float(el)

        if len(dummy) > 1:
            content_csv.append(dummy)
        
    # transform into panda data frame
        
    df = pd.DataFrame(content_csv, columns=column_names)
    
    # Export to csv
    name_csv = name + '.csv'
    df[1:-1].to_csv(name_csv)

        
    
    
    
    return df[1:-1]

# %%
df_eq = auto_to_csv(Eq,'Eq','EQ')
# Out:
# Relabeling done
# Saving to b.Eq, s.Eq, and d.Eq ... done
# Acquire the b. file
# Read file
# [['0', 'PT', 'TY', 'LAB', 'V_plc', 'L2-NORM', 'V_pkc', 'switch', 'delta', 'K_tau', 'tau_max', 'PAR(21)', 'PAR(22)', 'PAR(23)', 'PAR(24)', 'PAR(25)', 'PAR(26)', 'PAR(31)', 'PAR(32)', 'PAR(33)', 'PAR(34)', 'PAR(35)', 'PAR(36)', 'PAR(80)']]
# Rename branch
# Split content

# %%
df_PR = auto_to_csv(PO,'PO','PR')
# Out:
# Relabeling done

# %%
df_HB12P = auto_to_csv(HB12P,'HB12P','HB')

# %%
df_HB22P = auto_to_csv(HB22P,'HB22P','HB')

# %%
df_HB12Pm = auto_to_csv(HB12Pm,'HB12Pm','HB')

# %%
df_HB22Pm = auto_to_csv(HB22Pm,'HB22Pm','HB')

# %%
df_Hom1 = auto_to_csv(Hom1,'Hom1','HB')

# %%
df_Hom_2 = auto_to_csv(Hom_2,'Hom_2','HB')

# %%
import plotly.plotly as py
from plotly.graph_objs import *
from plotly.offline import iplot, init_notebook_mode
init_notebook_mode(connected=True)

# %%
trace_eq = Scatter(x=df_eq['V_plc'],
                  y=df_eq['PAR(22)'],
                  name='Equilibria',
                  mode = 'lines')
trace_per = Scatter(x=df_PR['V_plc'],
                  y=df_PR['PAR(22)'],
                  name='Periodic Orbit',
                   mode='lines')
trace_per_min = Scatter(x=df_PR['V_plc'],
                  y=df_PR['PAR(32)'],
                  name='Periodic Orbit',
                   mode='lines')
data = [trace_eq,trace_per,trace_per_min]
layout = Layout(title="Bifurcation diagram",
               xaxis=dict(title='V_plc'),
               yaxis=dict(title='[Ca]'))
fig = Figure(data=data, layout=layout)
iplot(fig)

# %%
Is_3 = run(e='PKC_HR_IPR',c='PKC_HR_IPR.per',dat='per6',ISW=1,PAR={1:0.6},ISP=2,EPSL= 1e-12, EPSU = 1e-12,NTST=200)
Is_4 = run(e='PKC_HR_IPR',c='PKC_HR_IPR.per',dat='per6', DS='-',ISW=1,SP=['BP0'],PAR={1:0.6},ISP=2,EPSL= 1e-12, EPSU = 1e-12,NTST=200)
Is2 = Is_3 + Is_4

# %%
Is_5 = run(e='PKC_HR_IPR',c='PKC_HR_IPR.per',dat='per3',ISW=1,PAR={1:0.3},ISP=2,EPSL= 1e-12, EPSU = 1e-12,NTST=200)
Is_6 = run(e='PKC_HR_IPR',c='PKC_HR_IPR.per',dat='per3', DS='-',ISW=1,SP=['BP0'],PAR={1:0.3},ISP=2,EPSL= 1e-12, EPSU = 1e-12,NTST=200)
Is3 = Is_5 + Is_6

# %%
#Is_3 = run(e='PKC_HR_IPR',c='PKC_HR_IPR.per',dat='per3',ISW=1,PAR={1:0.3},ISP=2,EPSL= 1e-12, EPSU = 1e-12,NTST=200)
#Is_4 = run(e='PKC_HR_IPR',c='PKC_HR_IPR.per',dat='per3', DS='-',ISW=1,SP=['BP0'],PAR={1:0.3},ISP=2,EPSL= 1e-12, EPSU = 1e-12,NTST=200)
#Is2 = Is_3 + Is_4

# %%
Is_5 = run(e='PKC_HR_IPR',c='PKC_HR_IPR.per',dat='per6',ISW=1,PAR={1:0.6},ISP=2,EPSL= 1e-12, EPSU = 1e-12,NTST=200)
Is_6 = run(e='PKC_HR_IPR',c='PKC_HR_IPR.per',dat='per6', DS='-',ISW=1,SP=['BP0'],PAR={1:0.6},ISP=2,EPSL= 1e-12, EPSU = 1e-12,NTST=200)
Is3 = Is_5 + Is_6

# %%
df_Is = auto_to_csv(Is,'Is','IS')

# %%
df_Is2 = auto_to_csv(Is2,'Is2','IS2')

# %%
df_Is3 = auto_to_csv(Is3,'Is3','IS3')

# %%
trace_eq = Scatter(x=df_eq['V_plc'],
                  y=df_eq['PAR(5)'],
                  name='Equilibria',
                  mode = 'lines')
trace_per = Scatter(x=df_PR['V_plc'],
                  y=df_PR['PAR(5)'],
                  name='Periodic Orbit',
                   mode='lines')
trace_per_min = Scatter(x=df_PR['V_plc'],
                  y=df_PR['PAR(32)'],
                  name='Periodic Orbit',
                   mode='lines')
tr_is = Scatter(x=df_Is['V_plc'],
                  y=df_Is['PAR(5)'],
                  name='Isola',
                  mode='lines')
tr_is_min = Scatter(x=df_Is['V_plc'],
                  y=df_Is['PAR(32)'],
                  name='Isola',
                  mode='lines')
tr_is2 = Scatter(x=df_Is2['V_plc'],
                  y=df_Is2['PAR(5)'],
                  name='Isola',
                  mode='lines')
tr_is2_min = Scatter(x=df_Is2['V_plc'],
                  y=df_Is2['PAR(32)'],
                  name='Isola',
                  mode='lines')
tr_is3 = Scatter(x=df_Is3['V_plc'],
                  y=df_Is3['PAR(5)'],
                  name='Isola',
                  mode='lines')
tr_is3_min = Scatter(x=df_Is3['V_plc'],
                  y=df_Is3['PAR(32)'],
                  name='Isola',
                  mode='lines')
data = [trace_eq,trace_per,trace_per_min,tr_is,tr_is_min,tr_is2,tr_is2_min,tr_is3,tr_is3_min]
# data = [trace_eq,trace_per,trace_per_min,tr_is,tr_is_min,tr_is2,tr_is2_min]
layout = Layout(title="Bifurcation diagram",
               xaxis=dict(title='V_plc'),
               yaxis=dict(title='[Ca]'))
fig = Figure(data=data, layout=layout)
iplot(fig)

# %%
HB12P = run(Eq('HB1'),c ='PKC_HR_IPR.eq',ISW=2,ICP=[1,2],DS=1e-3)

# %%
HB22P = run(Eq('HB2'),c ='PKC_HR_IPR.eq',ISW=2,ICP=[1,2],DS=1e-3,NMX=100000)

# %%
PD2P = run(PO1('PD1'),c='PKC_HR_IPR.per',ISW=2,ICP=[1,2,11],DS=1e-4)
PD2P1 = run(PD2P('EP1'))

# %%
SNP2P = run(PO1('LP3'),c='PKC_HR_IPR.per',ISW=2,ICP=[1,2,11],DS=1e-4)
SNP2P1 = run(SNP2P('EP1'))

# %%
df_HB12P = auto_to_csv(HB12P,'HB12P','HB_1')
df_HB22P = auto_to_csv(HB22P,'HB22P','HB_2')
df_PD2P1 = auto_to_csv(PD2P1,'PD2P1','PD_1')
df_SNP2P1 = auto_to_csv(SNP2P1,'SNP2P1','SNP_1')

# %%
slice1 = run(e='PKC_HR_IPR',c='PKC_HR_IPR.eq',PAR={2:0.01})

# %%
slicePO = run(slice1('HB1'),c='PKC_HR_IPR.per',SP=['BP0'])

# %%
slice2 = run(e='PKC_HR_IPR',c='PKC_HR_IPR.eq',PAR={2:0.2})

# %%
slicePO2 = run(slice1('HB2'),c='PKC_HR_IPR.per',SP=['BP0'])

# %%
slice3 = run(e='PKC_HR_IPR',c='PKC_HR_IPR.eq',PAR={2:14})

# %%
slicePO3 = run(slice3('HB1'),c='PKC_HR_IPR.per',SP=['BP0'])

# %%
slice4 = run(e='PKC_HR_IPR',c='PKC_HR_IPR.eq',PAR={2:20})

# %%
slicePO4 = run(slice4('HB1'),c='PKC_HR_IPR.per',SP=['BP0'])

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def auto_to_csv(branch,name,solution_type):
    """ The goal of this function is to save as a csv file the results of an AUTO continuation 
        and return a panda dataframe of the data"""
    """ Input:
        branch: an AUTO branch solution acquired using run(blablabla)
        name: The name of the output csv file, must be a string
        solution_type: 'EQ' for equilibrium, 'PR' for periodic orbit, 'HB' for Hopf two parameters continuation
            'LPPR' Limit point of periodic orbit
        
        Output:
        panda dataframe of the branch solution"""
    
    
    """Relabelling the branch solution """
    branch = rl(branch)
    """Saving the branch solution"""
    sv(branch,name)
    
    """Acquire the b. file"""
    print("Acquire the b. file")
    name_b = 'b.' + name
    content = None
    with open(name_b, 'r') as f:
        content = f.readlines()
    
    
    print("Read file")
    """Read the file from the beginning of the interesting part (depends on its type)"""
    
    for i in range(len(content)):
    
        if "PT" in content[i]:
            init = i
            break



            
    content_csv = [[el for el in content[init].split(' ') if len(el) > 0 and el != '\n']]
    print(content_csv)
        
    
        
    print("Rename branch")
    """ Rename the branch"""
    content_csv[0][0] = 'branch'
    column_names = content_csv[0]
    
    
    
    print("Split content")
    """Split and read the content"""
    for line in content:
        dummy = line.split(' ')
        dummy = [el for el in dummy if len(el) > 0 and el != '\n']
        if dummy[0] == '0':
            continue

        for el_i, el in enumerate(dummy):
            if el_i < 4:
                dummy[el_i] = int(el)
            else:
                dummy[el_i] = float(el)

        if len(dummy) > 1:
            content_csv.append(dummy)
        
    # transform into panda data frame
        
    df = pd.DataFrame(content_csv, columns=column_names)
    
    # Export to csv
    name_csv = name + '.csv'
    df[1:-1].to_csv(name_csv)

        
    
    
    
    return df[1:-1]

# %%
df_eq = auto_to_csv(slice1,'slice1','EQ')

# %%
df_PR = auto_to_csv(slicePO,'slicePO','PR')

# %%
trace_eq = Scatter(x=df_eqs[8]['ct'],
                  y=df_eqs[8]['PAR(5)'],
                  name='Equilibria',
                  mode = 'lines')
trace_per = Scatter(x=df_PRs[8]['ct'],
                  y=df_PRs[8]['PAR(5)'],
                  name='Periodic Orbit',
                   mode='lines')
trace_per_min = Scatter(x=df_PRs[8]['ct'],
                  y=df_PRs[8]['PAR(8)'],
                  name='Periodic Orbit',
                   mode='lines')
data = [trace_eq,trace_per,trace_per_min]
layout = Layout(title="Bifurcation diagram",
               xaxis=dict(title='Agonist'),
               yaxis=dict(title='[Ca]'))
fig = Figure(data=data, layout=layout)
iplot(fig)

# %%
df_per1[1:-1].to_csv('per1.csv')

# %%
df_per2[1:-1].to_csv('per2.csv')

# %%
df_per2[1:-1]
